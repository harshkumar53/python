# %%
import pandas as pd

# %% [markdown]
# - creating data set
#     - dicttonary of items
#     - lists of items
# - read data
# - selection of data
# - cleaning of data
# - visualizing the data
# - saving the data

# %%
movies = {
    'title' : ['RRR','DDLJ','PK','KGF','YJHD'],
    'rating' : [4.0,5.0,6.0,4.5,5.5],
    'year' : [2021,2022,2023,2021,2020]
}

pd.DataFrame(movies)
# Out:
#   title  rating  year
# 0   RRR     4.0  2021
# 1  DDLJ     5.0  2022
# 2    PK     6.0  2023
# 3   KGF     4.5  2021
# 4  YJHD     5.5  2020

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head(10) # return 5 row by default
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.tail() # return 5 row from bottom
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.sample(5) # return random row from data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9324   7518503830  20140723T000000  551000.0         4       1.50
# 14710  3876540410  20150413T000000  242000.0         3       2.25
# 5710   8944320280  20150402T000000  336000.0         3       2.50
# 2118   6762700340  20150427T000000  852000.0         3       3.00
# 19289  3416600490  20140731T000000  675000.0         3       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9324          1470      5100     1.5           0     0  ...      7
# 14710         1690      7292     1.0           0     0  ...      7
# 5710          2110      4549     2.0           0     0  ...      8
# 2118          2400      4000     2.0           0     0  ...      7
# 19289         1780      4252     2.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9324         1470              0      1946             0    98117  47.6769
# ...

# %%
df.info() # return info about data in concise form
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum() # check the null value
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe() # gives statistics of all the colums
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# Data Selection

# %% [markdown]
# - Row wise selection
#      - iloc : index based selection
#      - loc : label based selection
# - Colums wise selection
#      - dictionary like selection
#      - object like selection

# %%
df.iloc[4]
# Out:
# id                    1954400510
# date             20150218T000000
# price                   510000.0
# bedrooms                       3
# bathrooms                    2.0
# sqft_living                 1680
# sqft_lot                    8080
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1680
# sqft_basement                  0
# yr_built                    1987
# yr_renovated                   0
# zipcode                    98074
# lat                      47.6168
# long                    -122.045
# sqft_living15               1800
# sqft_lot15                  7503
# Name: 4, dtype: object

# %%
df.iloc[[1,5,59]]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 59  8079040320  20150223T000000   430000.0         4       3.00         1850
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 1       7242     2.0           0     0  ...      7        2170            400
# 5     101930     1.0           0     0  ...     11        3890           1530
# 59      9976     2.0           0     0  ...      8        1850              0
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1       1951          1991    98125  47.7210 -122.319           1690
# 5       2001             0    98053  47.6561 -122.005           4760
# 59      1991             0    98059  47.5059 -122.149           2270
#
#     sqft_lot15
# 1         7639
# 5       101930
# ...

# %%
df.iloc[[1,59,100],[0,1,2]]
# Out:
#              id             date     price
# 1    6414100192  20141209T000000  538000.0
# 59   8079040320  20150223T000000  430000.0
# 100  1952200240  20140611T000000  850830.0

# %%
df.iloc[15:26]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 15  9297300055  20150124T000000   650000.0         4       3.00         2950
# 16  1875500060  20140731T000000   395000.0         3       2.00         1890
# 17  6865200140  20140529T000000   485000.0         4       1.00         1600
# 18    16000397  20141205T000000   189000.0         2       1.00         1200
# 19  7983200060  20150424T000000   230000.0         3       1.00         1250
# 20  6300500875  20140514T000000   385000.0         4       1.75         1620
# 21  2524049179  20140826T000000  2000000.0         3       2.75         3050
# 22  7137970340  20140703T000000   285000.0         5       2.50         2270
# 23  8091400200  20140516T000000   252700.0         2       1.50         1070
# 24  3814700200  20141120T000000   329000.0         3       2.25         2450
# 25  1202000200  20141103T000000   233000.0         3       2.00         1710
#
# ...

# %%
df = df.set_index('id')
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[5631500400]['price']
# Out:
# np.float64(180000.0)

# %%
df.loc[[1202000200,9297300055]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 1202000200  20141103T000000  233000.0         3        2.0         1710
# 9297300055  20150124T000000  650000.0         4        3.0         2950
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1202000200      4697     1.5           0     0          5      6        1710
# 9297300055      5000     2.0           0     3          3      9        1980
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 1202000200              0      1941             0    98002  47.3048 -122.218
# 9297300055            970      1979             0    98126  47.5714 -122.375
#
#             sqft_living15  sqft_lot15
# id
# 1202000200           1030        4705
# 9297300055           2140        4000

# %% [markdown]
# - Single Column Selection
#     - dictionary likE selection
#     - object like selecion
# - Multiple Column SElection
#     - dictionary like Selection

# %%
df['price']
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.price
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df[['price','bedrooms']]
# Out:
#                price  bedrooms
# id
# 7129300520  221900.0         3
# 6414100192  538000.0         3
# 5631500400  180000.0         2
# 2487200875  604000.0         4
# 1954400510  510000.0         3
# ...              ...       ...
# 263000018   360000.0         3
# 6600060120  400000.0         4
# 1523300141  402101.0         2
# 291310100   400000.0         3
# 1523300157  325000.0         2
#
# [21613 rows x 2 columns]

# %%
import seaborn as sns

# %% [markdown]
# Manipulation and Cleaning
#     - removing rows and colums
#     - rename

# %%
df.yr_built.dtype
# Out:
# dtype('int64')

# %%
df.yr_built.astype('float64')
# Out:
# id
# 7129300520    1955.0
# 6414100192    1951.0
# 5631500400    1933.0
# 2487200875    1965.0
# 1954400510    1987.0
#                ...
# 263000018     2009.0
# 6600060120    2014.0
# 1523300141    2009.0
# 291310100     2004.0
# 1523300157    2008.0
# Name: yr_built, Length: 21613, dtype: float64

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
avg_age = round(df['age'].mean())
avg_age
# Out:
# 30

# %%
# using fillna method to handling numm value in age column

df['age'].fillna(avg_age, inplace=True)
df.head(20)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_5072\2192828947.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(avg_age, inplace=True)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# ...

# %%
df.dropna(subset=['embarked'],inplace=True)

# %%
df.drop('deck', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
embark = df['embark_town'].value_counts().idxmax()

# %%
df['embark_town'].value_counts().idxmin()
# Out:
# 'Queenstown'

# %%
df["embark_town"].fillna(embark, inplace=True)
df.head(10)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_5072\3458379034.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["embark_town"].fillna(embark, inplace=True)
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# ...
