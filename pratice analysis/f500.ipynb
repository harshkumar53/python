# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('f500.csv')
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
df.isnull().sum()
# Out:
# company                      0
# rank                         0
# revenues                     0
# revenue_change               2
# profits                      1
# assets                       0
# profit_change               64
# ceo                          0
# industry                     0
# sector                       0
# previous_rank                0
# country                      0
# hq_location                  0
# website                      0
# years_on_global_500_list     0
# employees                    0
# total_stockholder_equity     0
# dtype: int64

# %%
avg_revenue = round(df['revenue_change'].mean())
avg_revenue
# Out:
# 5

# %%
df['revenue_change'].fillna(avg_revenue, inplace=True)
df
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9636\976977018.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['revenue_change'].fillna(avg_revenue, inplace=True)
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# ...

# %%
avg_profit = round(df['profits'].mean())
avg_profit
# Out:
# 3055

# %%
df['profits'].fillna(avg_profit, inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9636\3641887632.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['profits'].fillna(avg_profit, inplace=True)

# %%
avg_profit_change = round(df['profit_change'].mean())
avg_profit_change
# Out:
# 24

# %%
df.profit_change.fillna(avg_profit_change, inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9636\2670597087.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.profit_change.fillna(avg_profit_change, inplace=True)

# %%
df.isnull().sum()
# Out:
# company                     0
# rank                        0
# revenues                    0
# revenue_change              0
# profits                     0
# assets                      0
# profit_change               0
# ceo                         0
# industry                    0
# sector                      0
# previous_rank               0
# country                     0
# hq_location                 0
# website                     0
# years_on_global_500_list    0
# employees                   0
# total_stockholder_equity    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
df.revenue_change.isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['previous_rank'].notnull()]
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
# check by conditions 

filter_profit = (
    df['revenues'] > 100000) & (df['profits'] < 0)
filter = df[filter_profit]
filter
# Out:
#                 company  rank  revenues  revenue_change  profits   assets  \
# 32  Japan Post Holdings    33    122990             3.6   -267.4  2631385
# 44              Chevron    45    107567           -18.0   -497.0   260078
#
#     profit_change               ceo                         industry  \
# 32         -107.5  Masatsugu Nagato  Insurance: Life, Health (stock)
# 44         -110.8    John S. Watson               Petroleum Refining
#
#         sector  previous_rank country    hq_location                  website  \
# 32  Financials             37   Japan   Tokyo, Japan  http://www.japanpost.jp
# 44      Energy             31     USA  San Ramon, CA   http://www.chevron.com
#
#     years_on_global_500_list  employees  total_stockholder_equity
# 32                        21     248384                     91532
# 44                        23      55200                    145556

# %%
# insert the id column

df.insert(0, 'id', range(1, len(df) + 1))

# %%
df = df.set_index('id')

# %%
df.head()
# Out:
#                      company  rank  revenues  revenue_change  profits  assets  \
# id
# 1                    Walmart     1    485873             0.8  13643.0  198825
# 2                 State Grid     2    315199            -4.4   9571.3  489838
# 3              Sinopec Group     3    267518            -9.1   1257.9  310726
# 4   China National Petroleum     4    262573           -12.3   1867.5  585619
# 5               Toyota Motor     5    254694             7.7  16899.3  437575
#
#     profit_change                  ceo                  industry  \
# id
# 1            -7.2  C. Douglas McMillon     General Merchandisers
# 2            -6.2              Kou Wei                 Utilities
# 3           -65.0            Wang Yupu        Petroleum Refining
# 4           -73.7        Zhang Jianhua        Petroleum Refining
# 5           -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                     sector  previous_rank country      hq_location  \
# id
# ...

# %%
rev = df['revenues'].describe()
rev
# Out:
# count       500.000000
# mean      55416.358000
# std       45725.478963
# min       21609.000000
# 25%       29003.000000
# 50%       40236.000000
# 75%       63926.750000
# max      485873.000000
# Name: revenues, dtype: float64

# %%
df.shape
# Out:
# (500, 17)

# %%
df['country'].value_counts()
# Out:
# country
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# India             7
# Brazil            7
# Italy             7
# Australia         7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Luxembourg        1
# Belgium           1
# Thailand          1
# Norway            1
# Malaysia          1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: count, dtype: int64

# %%
# filter the country south korea and return frist 5 rowa

korea = df['country'] == 'South Korea'
df[korea].head()
# Out:
#                   company  rank  revenues  revenue_change  profits  assets  \
# id
# 15    Samsung Electronics    15    173957            -2.0  19316.5  217104
# 78          Hyundai Motor    78     80701            -0.8   4659.0  148092
# 95            SK Holdings    95     72579           107.4    659.7   85332
# 177  Korea Electric Power   177     51500            -0.6   6074.1  147265
# 201        LG Electronics   201     47712            -4.6     66.2   31348
#
#      profit_change             ceo                        industry  \
# id
# 15            16.8    Oh-Hyun Kwon  Electronics, Electrical Equip.
# 78           -17.9  Mong-Koo Chung        Motor Vehicles and Parts
# 95           -86.0    Tae Won Chey              Petroleum Refining
# 177          -48.3    Hwan-Eik Cho                       Utilities
# 201          -39.8    Seong-Jin Jo  Electronics, Electrical Equip.
#
#                      sector  previous_rank      country  \
# id
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df.value_counts().sort_index()
# Out:
# company                       rank  revenues  revenue_change  profits  assets  profit_change  ceo                         industry                                  sector                      previous_rank  country      hq_location               website                      years_on_global_500_list  employees  total_stockholder_equity
# 3M                            361   30109     -0.5            5050.0   32906    4.5           Inge G. Thulin              Miscellaneous                             Industrials                 348            USA          St. Paul, MN              http://www.3m.com            23                        91584      10298                       1
# ...

# %%
df.value_counts(dropna=False)
# Out:
# company                       rank  revenues  revenue_change  profits  assets  profit_change  ceo                         industry                                  sector                      previous_rank  country      hq_location               website                      years_on_global_500_list  employees  total_stockholder_equity
# 3M                            361   30109     -0.5            5050.0   32906    4.5           Inge G. Thulin              Miscellaneous                             Industrials                 348            USA          St. Paul, MN              http://www.3m.com            23                        91584      10298                       1
# ...

# %%
df.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
sns.relplot(df, x='rank', y='revenues')

# %%
df.head()
# Out:
#                      company  rank  revenues  revenue_change  profits  assets  \
# id
# 1                    Walmart     1    485873             0.8  13643.0  198825
# 2                 State Grid     2    315199            -4.4   9571.3  489838
# 3              Sinopec Group     3    267518            -9.1   1257.9  310726
# 4   China National Petroleum     4    262573           -12.3   1867.5  585619
# 5               Toyota Motor     5    254694             7.7  16899.3  437575
#
#     profit_change                  ceo                  industry  \
# id
# 1            -7.2  C. Douglas McMillon     General Merchandisers
# 2            -6.2              Kou Wei                 Utilities
# 3           -65.0            Wang Yupu        Petroleum Refining
# 4           -73.7        Zhang Jianhua        Petroleum Refining
# 5           -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                     sector  previous_rank country      hq_location  \
# id
# ...

# %%
sns.relplot(df, x='revenues', y='rank', hue='previous_rank')
